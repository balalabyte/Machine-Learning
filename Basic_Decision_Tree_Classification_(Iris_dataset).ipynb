# %% [markdown]
# <a href="https://colab.research.google.com/github/balalabyte/Machine-Learning/blob/main/Basic_Decision_Tree_Classification_(Iris_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris

# %%
#loading our iris class into an object called 'iris'
iris=load_iris()

# %%
#iris object has some attributes

x=iris.data
y=iris.target

# %%
#Train-Test business
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(x,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
Y_train.shape
# Out:
# (120,)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf= DecisionTreeClassifier()

# %%
#Training our model on the train dataset
clf.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred= clf.predict(X_test )

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,y_pred)
# Out:
# 1.0

# %%
#plotting the tree to see how the descision is made
from sklearn.tree import plot_tree
from matplotlib.pylab import rcParams
rcParams['figure.figsize']= 80,50

plot_tree(clf)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.664\nsamples = 120\nvalue = [40, 36, 44]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.495\nsamples = 80\nvalue = [0, 36, 44]'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.219\nsamples = 40\nvalue = [0, 35, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.057\nsamples = 34\nvalue = [0, 33, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 33\nvalue = [0, 33, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5384615384615384, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...
